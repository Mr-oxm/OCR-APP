# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
import pandas as pd 
import numpy  as np


# %matplotlib inline

# %%
data = pd.read_csv("emnist-balanced-train.csv")
data_t = pd.read_csv("emnist-balanced-test.csv")

# %%
data_t.iloc[:,0].min(),data_t.iloc[:,0].max()
data.iloc[:,0].min(),data.iloc[:,0].max()
# Out:
# (0, 46)

# %%
x = data.iloc[:,1:].values
y=data.iloc[:,0].values
x_t = data_t.iloc[:,1:].values
y_t=data_t.iloc[:,0].values
x.shape,y.shape,x_t.shape,y_t.shape
# Out:
# ((112799, 784), (112799,), (18799, 784), (18799,))

# %%
x_train=x
x_test=x_t
y_train=y
y_test=y_t

# %%
x_train = x_train / 255
x_test = x_test / 255

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((112799, 784), (18799, 784), (112799,), (18799,))

# %%
plt.suptitle('Images')
for i in range(10):
    image = x_train[i].reshape((28,28))
    plt.subplot(2,5,i+1)
    plt.imshow(image,cmap="gray")

# %% [markdown]
# # Model:

# %%
model= Sequential([
    tf.keras.Input(shape=(784,)),
    Dense(units=512,activation="relu",name="layer1"),
    Dense(units=256,activation="relu",name="layer2"),
    Dense(units=47,activation="softmax",name="layer3")
],name="Mymodel"
)

# %%
model.summary()
# Out:
# Model: "Mymodel"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer1 (Dense)              (None, 512)               401920
#
#  layer2 (Dense)              (None, 256)               131328
#
#  layer3 (Dense)              (None, 47)                12079
#
# =================================================================
# Total params: 545,327
# Trainable params: 545,327
# Non-trainable params: 0
# _________________________________________________________________

# %%
[layer1,layer2,layer3]=model.layers

w1,b1=layer1.get_weights()
w2,b2=layer2.get_weights()
w3,b3=layer3.get_weights()

print(f"w1 shape:{w1.shape} , b1 shape: {b1.shape}")
print(f"w2 shape:{w2.shape} , b2 shape: {b2.shape}")
print(f"w3 shape:{w3.shape} , b3 shape: {b3.shape}")
# Out:
# w1 shape:(784, 512) , b1 shape: (512,)
# w2 shape:(512, 256) , b2 shape: (256,)
# w3 shape:(256, 47) , b3 shape: (47,)

# %%
model.compile(loss=SparseCategoricalCrossentropy(from_logits=True)
            ,optimizer=Adam(learning_rate=1e-3)
            , metrics=["accuracy"]
)

# %%
x_train=np.array(x_train)

# %%
Letter_recognition=model.fit(
    x_train,y_train,
    epochs=100,batch_size=32
)
# Out:
# Epoch 1/100
# c:\Users\emara\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\backend.py:5582: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 3525/3525 [==============================] - 20s 6ms/step - loss: 0.8057 - accuracy: 0.7501
# Epoch 2/100
# 3525/3525 [==============================] - 18s 5ms/step - loss: 0.4940 - accuracy: 0.8303
# Epoch 3/100
# 3525/3525 [==============================] - 18s 5ms/step - loss: 0.4164 - accuracy: 0.8520
# Epoch 4/100
# 3525/3525 [==============================] - 18s 5ms/step - loss: 0.3709 - accuracy: 0.8652
# Epoch 5/100
# 3525/3525 [==============================] - 18s 5ms/step - loss: 0.3348 - accuracy: 0.8750
# Epoch 6/100
# 3525/3525 [==============================] - 18s 5ms/step - loss: 0.3078 - accuracy: 0.8835
# Epoch 7/100
# 3525/3525 [==============================] - 18s 5ms/step - loss: 0.2860 - accuracy: 0.8902
# Epoch 8/100
# 3525/3525 [==============================] - 18s 5ms/step - loss: 0.2654 - accuracy: 0.8959
# Epoch 9/100
# 3525/3525 [==============================] - 11s 3ms/step - loss: 0
100
# 3525/3525 [==============================] - 12s 3ms/step - loss: 0.1284 - accuracy: 0.9603
# Epoch 61/100
# 3525/3525 [==============================] - 11s 3ms/step - loss: 0.1224 - accuracy: 0.9605
# Epoch 62/100
# 3525/3525 [==============================] - 11s 3ms/step - loss: 0.1233 - accuracy: 0.9599
# Epoch 63/100
# 3525/3525 [==============================] - 12s 3ms/step - loss: 0.1221 - accuracy: 0.9612
# Epoch 64/100
# 3525/3525 [==============================] - 11s 3ms/step - loss: 0.1211 - accuracy: 0.9612
# Epoch 65/100
# 3525/3525 [==============================] - 12s 3ms/step - loss: 0.1250 - accuracy: 0.9612
# Epoch 66/100
# 3525/3525 [==============================] - 12s 3ms/step - loss: 0.1197 - accuracy: 0.9618
# Epoch 67/100
# 3525/3525 [==============================] - 12s 3ms/step - loss: 0.1243 - accuracy: 0.9614
# Epoch 68/100
# 3525/3525 [==============================] - 12s 3ms/step - loss: 0.1223 - accuracy: 0.9616
# Epoch 69/100
# 3525/3525 [==============================] - 12s 3ms/step - loss: 0.1215 - accuracy: 0.9631
# Epoch 70/100
# 3525/3525 [==============================] - 12s 3ms/step - loss: 0.1197 - accuracy: 0.9630
# Epoch 71/100
# 3525/3525 [==============================] - 12s 3ms/step - loss: 0.1248 - accuracy: 0.9630
# Epoch 72/100
# 3525/3525 [==============================] - 12s 3ms/step - loss: 0.1226 - accuracy: 0.9634
# Epoch 73/100
# 3525/3525 [==============================] - 13s 4ms/step - loss: 0.1211 - accuracy: 0.9641
# Epoch 74/100
# 3525/3525 [==============================] - 12s 3ms/step - loss: 0.1209 - accuracy: 0.9641
# Epoch 75/100
# 3525/3525 [==============================] - 14s 4ms/step - loss: 0.1193 - accuracy: 0.9644
# Epoch 76/100
# 3525/3525 [==============================] - 14s 4ms/step - loss: 0.1220 - accuracy: 0.9637
# Epoch 77/100
# 3525/3525 [==============================] - 13s 4ms/step - loss: 0.1212 - accuracy: 0.9646
# Epoch 78/100
# 3525/3525 [==============================] - 13s 4ms/step - loss: 0.1146 - accuracy: 0.9652
# Epoch 79/100
# 3525/3525 [==============================] - 13s 4ms/step - loss: 0.1184 - accuracy: 0.9645
# Epoch 80/100
# 3525/3525 [==============================] - 13s 4ms/step - loss: 0.1193 - accuracy: 0.9654
# Epoch 81/100
# 3525/3525 [==============================] - 14s 4ms/step - loss: 0.1176 - accuracy: 0.9661
# Epoch 82/100
# 3525/3525 [==============================] - 14s 4ms/step - loss: 0.1198 - accuracy: 0.9657
# Epoch 83/100
# 3525/3525 [==============================] - 13s 4ms/step - loss: 0.1212 - accuracy: 0.9655
# Epoch 84/100
# 3525/3525 [==============================] - 13s 4ms/step - loss: 0.1210 - accuracy: 0.9662
# Epoch 85/100
# 3525/3525 [==============================] - 14s 4ms/step - loss: 0.1194 - accuracy: 0.9664
# Epoch 86/100
# 3525/3525 [==============================] - 14s 4ms/step - loss: 0.1176 - accuracy: 0.9663
# Epoch 87/100
# 3525/3525 [==============================] - 14s 4ms/step - loss: 0.1128 - accuracy: 0.9670
# Epoch 88/100
# 3525/3525 [==============================] - 14s 4ms/step - loss: 0.1236 - accuracy: 0.9664
# Epoch 89/100
# 3525/3525 [==============================] - 14s 4ms/step - loss: 0.1087 - accuracy: 0.9681
# Epoch 90/100
# 3525/3525 [==============================] - 13s 4ms/step - loss: 0.1203 - accuracy: 0.9671
# Epoch 91/100
# 3525/3525 [==============================] - 14s 4ms/step - loss: 0.1110 - accuracy: 0.9675
# Epoch 92/100
# 3525/3525 [==============================] - 14s 4ms/step - loss: 0.1221 - accuracy: 0.9669
# Epoch 93/100
# 3525/3525 [==============================] - 13s 4ms/step - loss: 0.1132 - accuracy: 0.9686
# Epoch 94/100
# 3525/3525 [==============================] - 13s 4ms/step - loss: 0.1171 - accuracy: 0.9682
# Epoch 95/100
# 3525/3525 [==============================] - 13s 4ms/step - loss: 0.1129 - accuracy: 0.9688
# Epoch 96/100
# 3525/3525 [==============================] - 13s 4ms/step - loss: 0.1147 - accuracy: 0.9686
# Epoch 97/100
# 3525/3525 [==============================] - 13s 4ms/step - loss: 0.1140 - accuracy: 0.9682
# Epoch 98/100
# 3525/3525 [==============================] - 13s 4ms/step - loss: 0.1134 - accuracy: 0.9690
# Epoch 99/100
# 3525/3525 [==============================] - 13s 4ms/step - loss: 0.1175 - accuracy: 0.9686
# Epoch 100/100
# 3525/3525 [==============================] - 13s 4ms/step - loss: 0.1101 - accuracy: 0.9700

# %%
plt.subplot(1, 2, 1)
plt.plot(Letter_recognition.history['accuracy'], label='Training Accuracy')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()


plt.subplot(1, 2, 2)
plt.plot(Letter_recognition.history['loss'], label='Training Loss')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
prediction_model=model.predict(x_test)
# Out:
# 588/588 [==============================] - 1s 2ms/step

# %%
prediction_p=tf.nn.softmax(prediction_model)
predicted_labels = np.argmax(prediction_p, axis=1)

# %%
loss,Accuracy=model.evaluate(x_test,y_test)
# Out:
# 588/588 [==============================] - 1s 2ms/step - loss: 4.4543 - accuracy: 0.8336

# %%
Accuracy
# Out:
# 0.8335549831390381

# %% [markdown]
# # Testing Model :

# %%
ascii_map = {} 
# Mapping over the emnist-balanced-mapping.txt contianing the assci vlaues of every output of the ann
with open("emnist-balanced-mapping.txt", "r") as file: 
        lines = file.readlines() 
        for line in lines: 
                index, ascii_value = map(int, line.split()) 
                character = chr(ascii_value) 
                ascii_map[index] = character

# %%
def letter(prediction): 
        return ascii_map[prediction]

# %%
plt.suptitle("Class Prediction\n(Actual vs. Predicted)")
for i in range(6):
    image = x_test[i].reshape((28,28))
    plt.subplot(2,3,i+1)
    plt.title(f"Actual : {letter(y_test[i])} \n Predicted: {letter(predicted_labels[i])}")
    plt.imshow(image,cmap="gray")
    plt.tight_layout()

# %% [markdown]
# # Model Evaluation :

# %%
conf_matrix = confusion_matrix(y_test,predicted_labels)
accuracy = accuracy_score(y_test, predicted_labels)
precision = precision_score(y_test, predicted_labels, average='weighted')  
recall = recall_score(y_test, predicted_labels, average='weighted')  
f1 = f1_score(y_test, predicted_labels, average='weighted')  

print("Accuracy: {:.2f}%".format(accuracy * 100))
print("Precision: {:.2f}".format(precision))
print("Recall: {:.2f}".format(recall))
print("F1 Score: {:.2f}".format(f1))
# Out:
# Accuracy: 83.36%
# Precision: 0.83
# Recall: 0.83
# F1 Score: 0.83

# %% [markdown]
# # Confusion Matrix for Class Prediction :

# %%
sns.heatmap(conf_matrix,cmap='viridis')
# Out:
# <Axes: >

# %%
model.save("ocr-full.h5")

# %%
new_model= tf.keras.models.load_model('ocr-full.h5')

# %% [markdown]
# # **Testing one letter**

# %%
import numpy as np
from PIL import Image 
import cv2

image_path = 'letter.png'
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)


image = cv2.resize(image, (28, 28))
# Invert the image
image = cv2.bitwise_not(image)


# Rotate the image by -90 degrees
image = cv2.rotate(image, cv2.ROTATE_90_COUNTERCLOCKWISE)

#Flip on x axis
image= cv2.flip(image, 0)

plt.imshow(image, cmap="gray")

image_array = image / 255.0
image_array = image_array.reshape(1, 784)


predicted_probabilities = new_model.predict(image_array)
prediction_p=tf.nn.softmax(predicted_probabilities)
predicted_labels = np.argmax(prediction_p) 

print("Predicted Label:", letter(predicted_labels))
# Out:
# 1/1 [==============================] - 0s 45ms/step
# Predicted Label: A

# %% [markdown]
# # **Testing one sentense**

# %%
import cv2
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('letter3.png')

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Threshold the image to binary
_, binary = cv2.threshold(gray, 128, 255, cv2.THRESH_BINARY_INV)

# Find contours of the characters
contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Sort contours based on their x-coordinate
contours = sorted(contours, key=lambda x: cv2.boundingRect(x)[0])

predictions = []

for contour in contours:
    # Get bounding box coordinates for each character
    x, y, w, h = cv2.boundingRect(contour)
    
    # Extract individual character using slicing and resize it to 28x28 pixels 
    char_image = gray[y:y+h, x:x+w]
    
    # Apply properties to the segment
    img_resized = cv2.resize(char_image, (28, 28))
    img_resized = cv2.bitwise_not(img_resized)
    img_resized = cv2.flip(img_resized, 0)
    img_resized = np.rot90(img_resized, -1)
    img_resized = img_resized / 255.0
    
    # Flatten image
    img_flattened = img_resized.reshape(1, 784)
    
    predicted_probabilities = new_model.predict(img_flattened)
    prediction_p = tf.nn.softmax(predicted_probabilities)
    predicted_labels = np.argmax(prediction_p)
    
    # Append each character's image into a list 
    predictions.append(letter(predicted_labels))

predictions
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# ['B', 'M', 'A', 'R']
